# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#Challenge 1
df = pd.read_csv("compas.csv")

# %%
#Challenge 2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 53 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7214 non-null   int64
#  1   name                     7214 non-null   object
#  2   first                    7214 non-null   object
#  3   last                     7214 non-null   object
#  4   compas_screening_date    7214 non-null   object
#  5   sex                      7214 non-null   object
#  6   dob                      7214 non-null   object
#  7   age                      7214 non-null   int64
#  8   age_cat                  7214 non-null   object
#  9   race                     7214 non-null   object
#  10  juv_fel_count            7214 non-null   int64
#  11  decile_score             7214 non-null   int64
#  12  juv_misd_count           7214 non-null   int64
#  13  juv_other_count          7214 non-null   int64
# ...

# %%
#Challenge 3
#Missing values,  Answered in peardeck

# %%
#Challenge 4
sns.countplot(x=df["sex"])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#Challenge 5
sns.countplot(x=df["age_cat"])
# Out:
# <AxesSubplot:xlabel='age_cat', ylabel='count'>

# %%
#Challenge 6
sns.histplot(data=df, x="age", kde=True, bins=8)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
#Challenge 7 - part 1
df["c_jail_in"] = pd.to_datetime(df["c_jail_in"])
df["c_jail_out"] = pd.to_datetime(df["c_jail_out"])
df["total_time_jail"] = (df["c_jail_out"] - df["c_jail_in"]).dt.days

# %%
#part 2
sns.set_style("whitegrid")
sns.scatterplot(data=df, x="total_time_jail", y="age")
ax = plt.gca()
ax.set_xlabel("Days in Jail")
ax.set_ylabel("Age")
ax.set_title("Days in Jail After Frist Charge")
# Out:
# Text(0.5, 1.0, 'Days in Jail After Frist Charge')

# %%
#Challenge 8 - Part 1
race_count = df['race'].value_counts()
race_count
# Out:
# African-American    3696
# Caucasian           2454
# Hispanic             637
# Other                377
# Asian                 32
# Native American       18
# Name: race, dtype: int64

# %%
#Challenge 8 - Part 2
sns.set_theme(style="whitegrid")
sns.countplot(x=df["race"])
plt.xticks(fontsize = 8)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Other'),
#   Text(1, 0, 'African-American'),
#   Text(2, 0, 'Caucasian'),
#   Text(3, 0, 'Hispanic'),
#   Text(4, 0, 'Native American'),
#   Text(5, 0, 'Asian')])

# %%
#Challenge 9 - Part 1
compas_count = df['decile_score.1'].value_counts()
compas_count
# Out:
# 1     1440
# 2      941
# 4      769
# 3      747
# 5      681
# 6      641
# 7      592
# 8      512
# 9      508
# 10     383
# Name: decile_score.1, dtype: int64

# %%
#part 2
sns.set_theme(style="whitegrid")
sns.countplot(x=df["decile_score.1"])
ax = plt.gca()
ax.set_xlabel("COMPAS Score")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Challenge 10
sns.countplot(data=df, x="decile_score.1", hue="sex")
ax = plt.gca()
ax.set_xlabel("COMPAS Score")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Challenge 11
sns.set_style("whitegrid")
sns.lineplot(data=df, x="age", y="decile_score.1", hue="sex")
ax = plt.gca()
ax.set_xlabel("Age")
ax.set_ylabel("COMPAS Score")
# Out:
# Text(0, 0.5, 'COMPAS Score')

# %%
#Challenge 12
sns.countplot(data=df, x="decile_score.1", hue="race")
ax = plt.gca()
ax.set_xlabel("COMPAS Score")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.set_style("whitegrid")
sns.lineplot(data=df, x="total_time_jail", y="decile_score.1")
ax = plt.gca()
ax.set_xlabel("Total Time in Jail")
ax.set_ylabel("COMPAS Score")
# Out:
# Text(0, 0.5, 'COMPAS Score')

# %%
#Challenge 14
#I would say that the COMPAS Score was not correct
sns.set_theme(style="whitegrid")
sns.countplot(data=df, x="two_year_recid", hue="decile_score.1")
ax = plt.gca()
ax.set_xlabel("Two Year Recid")
ax.set_ylabel("Count")
ax.set_title("Who Actually Commits a Crime Again?")
# Out:
# Text(0.5, 1.0, 'Who Actually Commits a Crime Again?')
