# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv("pirates.csv") # This requires the csv file to be in the same folder as this Jupyter notebook.
df.head()
# Out:
#    id     sex   age  height  weight headband college  tattoos  tchests  \
# 0   1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1   2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2   3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3   4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4   5  female  41.0  157.85    58.4      yes   JSSFP        9        6
#
#   parrots favorite.pirate sword.type  eyepatch  sword.time  beard.length  \
# 0       0    Jack Sparrow    cutlass         1        0.58            16
# 1       0    Jack Sparrow    cutlass         0        1.11            21
# 2       1    Jack Sparrow    cutlass         1        1.44            19
# 3       2    Jack Sparrow   scimitar         1       36.11             2
# 4       4            Hook    cutlass         1        0.11             0
#
#         fav.pixar  grogg
# 0  Monsters, Inc.     11
# 1          WALL-E      9
# 2      Inside Out      7
# 3      Inside Out      9
# 4      Inside Out     14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   object
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
#  16  grogg            1000 non-null   int64
# dtypes: float64(4), int64(6), object(7)
# memory usage: 132.9+ KB

# %%
column_type = df["parrots"].dtype

# %%
column_type
# Out:
# dtype('O')

# %%
ID = 1
for column in df.columns:
    for row in range(len(df["id"])):
        if pd.isna(df.loc[row, column]):
            print(row)
            print(column)
# Out:
# 33
# age
# 999
# headband
# 634
# favorite.pirate
# 136
# sword.time

# %%
# Challenge 3
# Technique 1
# This drops all rows that contain a null value

df.dropna(inplace=True)
df.reset_index(inplace=True)

# %%
# Challenge 3
# Technique 2
# Drops just the age row that features a null

#df.drop(33, inplace=True)

# %%
# Challenge 3
# Technique 3
# Reassigns the missing value in age to the mean of ages

df.loc[33, "age"] = df["age"].mean()

# %%
# Challenge 3
# Technique 4
# Reassigns the missing value in favorite.pirate to the mode

df.loc[634, "favorite.pirate"] = df["favorite.pirate"].mode()[0]

# %%
# Challenge 3
# Technique 5
# Assigns the missing age value to a random integer in the range of the smallest age in the dataset and the largest age in dataset
import random
df.loc[33, "age"] = random.randint(df["age"].min(), df["age"].max())

# %%
#Challenge 4
df["sex"].unique()
# Out:
# array(['male', 'female', 'other'], dtype=object)

# %%
#Part 1
mean = df['age'].mean()
df['age'].mean()
print("Average age of pirates is:")
print(mean)
# Out:
# Average age of pirates is:
# 27.3714859437751

# %%
femaleAges = []
for i in range(len(df)):
    if df.loc[i, "sex"] == "female":
        femaleAges.append(df.loc[i, "age"])

# %%
#Part 2
sum(femaleAges)/len(femaleAges)
# Out:
# 29.932900432900432

# %%
df["weight_lb"] = df["weight"]*2.2
percent = (df["weight_lb"] < 100).mean() * 100
print("The percetnage of pirates the weight less than 100 pounds is:")
print(percent)
# Out:
# The percetnage of pirates the weight less than 100 pounds is:
# 0.8032128514056224

# %%
#Challenge 5
#min to min smallest height
#idx = df["height"].idxmin()
#print(idx)
min = df["height"].min()
idx = df.index[df['height'] == 129.83].tolist()
print(idx)
# Out:
# [37]

# %%
#idx max to find heaviest 
idx = df["weight"].idxmax()
print(idx)
# Out:
# 1

# %%
#Mode of movie column
df["fav.pixar"].mode()
# Out:
# 0    Inside Out
# Name: fav.pixar, dtype: object

# %%
#Challenge 6
#Part 1
#Step 1- median
#Average/median number of eye patches worn
print("Median number of eyepatches worn is:")
df['eyepatch'].median()
# Out:
# Median number of eyepatches worn is:
# 1.0

# %%
#Step 2 -average
print("Average number of eyepatches worn is:")
df['eyepatch'].mean()
# Out:
# Average number of eyepatches worn is:
# 0.6576305220883534

# %%
df.loc[35, "parrots"] = 1 
idx = 0
for i in df["parrots"]:
    df.loc[idx, "parrots"] = int(i)
    idx = idx + 1

# %%
#Part 2
#Step 1 - average
print("Average number of parrots owned is:")
df['parrots'].mean()
# Out:
# Average number of parrots owned is:
# 2.819277108433735

# %%
#Step 2 - median
print("Median number of parrots owned is:")
df['parrots'].median()
# Out:
# Median number of parrots owned is:
# 2.0

# %%
#Challenge 7
newrow = pd.read_csv("PirateNewRow.csv")
combined_df = pd.concat([df, newrow], ignore_index = True)
combined_df.drop(["index"], axis = 1, inplace = False)
# Out:
#        id     sex   age  height  weight headband college  tattoos  tchests  \
# 0       1    male  28.0  173.11   70.50      yes   JSSFP        9        0
# 1       2    male  31.0  209.25  105.60      yes   JSSFP        9       11
# 2       3    male  26.0  169.95   77.10      yes    CCCC       10       10
# 3       4  female  31.0  144.29   58.50       no   JSSFP        2        0
# 4       5  female  41.0  157.85   58.40      yes   JSSFP        9        6
# ..    ...     ...   ...     ...     ...      ...     ...      ...      ...
# 992   996    male  26.0  178.83   70.80      yes    CCCC       14       11
# 993   997  female  34.0  157.20   53.60      yes   JSSFP       13       48
# 994   998    male  36.0  175.74   72.40      yes   JSSFP        9       95
# 995   999    male  30.0  175.24   70.20      yes   JSSFP        9        6
# 996  1001  female  43.0  187.30   97.12       no    CCCC       17        3
#
#     parrots favorite.pirate sword.type  eyepatch  sword.time  beard.length  \
# 0         0    Jack Sparrow    cutlass         1        0.58            16
# 1         0    Jack Sparrow    cutlass         0        1.11            21
# 2         1    Jack Sparrow    cutlass         1        1.44            19
# 3         2    Jack Sparrow   scimitar         1       36.11             2
# 4         4            Hook    cutlass         1        0.11             0
# ..      ...             ...        ...       ...         ...           ...
# 992       2    Jack Sparrow    cutlass         0        0.46            20
# 993       2            Hook    cutlass         0        0.15             0
# 994      14    Jack Sparrow    cutlass         1        1.28            18
# 995       0      Lewis Scot    cutlass         1        0.21            24
# 996       0      Blackbeard    cutlass         0        0.67             0
#
#            fav.pixar  grogg  weight_lb
# 0     Monsters, Inc.     11     155.10
# 1             WALL-E      9     232.32
# 2         Inside Out      7     169.62
# 3         Inside Out      9     128.70
# 4         Inside Out     14     128.48
# ..               ...    ...        ...
# 992               Up     13     155.76
# 993     Finding Nemo      8     117.92
# 994  The Incredibles     11     159.28
# 995       Inside Out     10     154.44
# 996     Finding Nemo      0        NaN
#
# [997 rows x 18 columns]

# %%
#Print challenge 7
combined_df.tail(-5)
# Out:
#      index    id     sex   age  height  weight headband college  tattoos  \
# 5      5.0     6    male  26.0  190.20   85.40      yes    CCCC        7
# 6      6.0     7  female  31.0  158.05   59.60      yes   JSSFP        9
# 7      7.0     8  female  31.0  172.52   74.50      yes   JSSFP        5
# 8      8.0     9  female  28.0  164.57   68.70      yes   JSSFP       12
# 9      9.0    10    male  30.0  183.52   84.70      yes   JSSFP       12
# ..     ...   ...     ...   ...     ...     ...      ...     ...      ...
# 992  995.0   996    male  26.0  178.83   70.80      yes    CCCC       14
# 993  996.0   997  female  34.0  157.20   53.60      yes   JSSFP       13
# 994  997.0   998    male  36.0  175.74   72.40      yes   JSSFP        9
# 995  998.0   999    male  30.0  175.24   70.20      yes   JSSFP        9
# 996    NaN  1001  female  43.0  187.30   97.12       no    CCCC       17
#
#      tchests parrots favorite.pirate sword.type  eyepatch  sword.time  \
# 5         19       0    Jack Sparrow    cutlass         1        0.59
# 6          1       7      Blackbeard    cutlass         0        3.01
# 7         13       7            Hook    cutlass         1        0.06
# 8         37       2        Anicetus    cutlass         0        0.74
# 9         69       4    Jack Sparrow    cutlass         1        0.71
# ..       ...     ...             ...        ...       ...         ...
# 992       11       2    Jack Sparrow    cutlass         0        0.46
# 993       48       2            Hook    cutlass         0        0.15
# 994       95      14    Jack Sparrow    cutlass         1        1.28
# 995        6       0      Lewis Scot    cutlass         1        0.21
# 996        3       0      Blackbeard    cutlass         0        0.67
#
#      beard.length            fav.pixar  grogg  weight_lb
# 5              17  Monsters University      7     187.88
# 6               1                 Cars      9     131.12
# 7               1           Inside Out     12     163.90
# 8               1          Toy Story 3     16     151.14
# 9              25  Monsters University      9     186.34
# ..            ...                  ...    ...        ...
# 992            20                   Up     13     155.76
# 993             0         Finding Nemo      8     117.92
# 994            18      The Incredibles     11     159.28
# 995            24           Inside Out     10     154.44
# 996             0         Finding Nemo      0        NaN
#
# [992 rows x 19 columns]

# %%
#Challenge 8
newcolumn = pd.read_csv("PirateNewColumn.csv")
merged_df = pd.merge(combined_df, newcolumn, on='id', how='inner')
merged_df.head(20)
# Out:
#     index  id     sex   age  height  weight headband college  tattoos  \
# 0     0.0   1    male  28.0  173.11    70.5      yes   JSSFP        9
# 1     1.0   2    male  31.0  209.25   105.6      yes   JSSFP        9
# 2     2.0   3    male  26.0  169.95    77.1      yes    CCCC       10
# 3     3.0   4  female  31.0  144.29    58.5       no   JSSFP        2
# 4     4.0   5  female  41.0  157.85    58.4      yes   JSSFP        9
# 5     5.0   6    male  26.0  190.20    85.4      yes    CCCC        7
# 6     6.0   7  female  31.0  158.05    59.6      yes   JSSFP        9
# 7     7.0   8  female  31.0  172.52    74.5      yes   JSSFP        5
# 8     8.0   9  female  28.0  164.57    68.7      yes   JSSFP       12
# 9     9.0  10    male  30.0  183.52    84.7      yes   JSSFP       12
# 10   10.0  11  female  25.0  162.49    63.5      yes    CCCC       10
# 11   11.0  12    male  20.0  163.65    70.0      yes    CCCC       14
# 12   12.0  13  female  24.0  171.04    72.6      yes    CCCC        8
# 13   13.0  14    male  26.0  177.99    78.2      yes    CCCC        9
# 14   14.0  15  female  45.0  167.65    65.4      yes   JSSFP       14
# 15   15.0  16  female  40.0  165.10    65.7      yes   JSSFP        8
# 16   16.0  17    male  21.0  177.52    72.7      yes    CCCC       11
# 17   17.0  18  female  30.0  158.30    65.6      yes   JSSFP        7
# 18   18.0  19  female  35.0  173.07    72.8      yes   JSSFP        7
# 19   19.0  20    male  26.0  175.45    69.0      yes    CCCC       14
#
#     tchests parrots favorite.pirate sword.type  eyepatch  sword.time  \
# 0         0       0    Jack Sparrow    cutlass         1        0.58
# 1        11       0    Jack Sparrow    cutlass         0        1.11
# 2        10       1    Jack Sparrow    cutlass         1        1.44
# 3         0       2    Jack Sparrow   scimitar         1       36.11
# 4         6       4            Hook    cutlass         1        0.11
# 5        19       0    Jack Sparrow    cutlass         1        0.59
# 6         1       7      Blackbeard    cutlass         0        3.01
# 7        13       7            Hook    cutlass         1        0.06
# 8        37       2        Anicetus    cutlass         0        0.74
# 9        69       4    Jack Sparrow    cutlass         1        0.71
# 10        1       3      Blackbeard    cutlass         1        0.78
# 11        5       3    Jack Sparrow    cutlass         0        0.47
# 12        6       0      Lewis Scot    cutlass         0        0.53
# 13       12       3    Jack Sparrow    cutlass         1        1.33
# 14       70       0            Hook    cutlass         1        0.33
# 15        3       1            Hook   scimitar         1       27.56
# 16        3       0    Jack Sparrow    cutlass         0        0.33
# 17      107       3      Blackbeard    cutlass         0        1.55
# 18       75      14            Hook    cutlass         0        0.72
# 19       30       3    Jack Sparrow    cutlass         0        0.40
#
#     beard.length            fav.pixar  grogg  weight_lb    favorite.sea
# 0             16       Monsters, Inc.     11     155.10     Caspian Sea
# 1             21               WALL-E      9     232.32         Red Sea
# 2             19           Inside Out      7     169.62     Chilean Sea
# 3              2           Inside Out      9     128.70      Bering Sea
# 4              0           Inside Out     14     128.48    Labrador Sea
# 5             17  Monsters University      7     187.88       Black Sea
# 6              1                 Cars      9     131.12      Baltic Sea
# 7              1           Inside Out     12     163.90   Norwegian Sea
# 8              1          Toy Story 3     16     151.14    Labrador Sea
# 9             25  Monsters University      9     186.34      Ryukyu Sea
# 10             1           Inside Out      7     139.70      Ryukyu Sea
# 11            27       Monsters, Inc.      8     154.00   Caribbean Sea
# 12             0       Monsters, Inc.     12     159.72  Southern Ocean
# 13            19           Inside Out      7     172.04    Labrador Sea
# 14             0  Monsters University      9     143.88      Aegean Sea
# 15             1      The Incredibles     10     144.54   Norwegian Sea
# 16            20         Finding Nemo     15     159.94     Arabian Sea
# 17             0       Monsters, Inc.      8     144.32  Tyrrhenian Sea
# 18             0         Finding Nemo     11     160.16        Java Sea
# 19            27               WALL-E     10     151.80     Andaman Sea
