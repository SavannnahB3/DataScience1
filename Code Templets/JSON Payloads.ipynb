# %%
import pandas as pd
import seaborn as sns
from io import StringIO

# %%
import requests

url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.psjB_D-orXG1KvvRQ8Y-O0Ohs6_mezLFp2R1Fda8W5g"
}

response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response = response.json()
tv = response["results"][0]

# %%
response
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg',
#    'first_air_date': '2008-01-20',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'name': 'Breaking Bad',
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "When Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 309.361,
#    'poster_path': '/3xnWaLQjelJDDF7LT1WBo6f4BRe.jpg',
#    'vote_average': 8.9,
#    'vote_count': 12409},
#   {'backdrop_path': '/rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg',
#    'first_air_date': '2021-11-06',
#    'genre_ids': [16, 18, 10765, 10759],
#    'id': 94605,
#    'name': 'Arcane',
#    'origin_country': ['US'],
# ...

# %%
tv
# Out:
# {'backdrop_path': '/tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg',
#  'first_air_date': '2008-01-20',
#  'genre_ids': [18, 80],
#  'id': 1396,
#  'name': 'Breaking Bad',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_name': 'Breaking Bad',
#  'overview': "When Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#  'popularity': 309.361,
#  'poster_path': '/3xnWaLQjelJDDF7LT1WBo6f4BRe.jpg',
#  'vote_average': 8.9,
#  'vote_count': 12409}

# %%
response
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg',
#    'first_air_date': '2008-01-20',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'name': 'Breaking Bad',
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "When Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 309.361,
#    'poster_path': '/3xnWaLQjelJDDF7LT1WBo6f4BRe.jpg',
#    'vote_average': 8.9,
#    'vote_count': 12409},
#   {'backdrop_path': '/rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg',
#    'first_air_date': '2021-11-06',
#    'genre_ids': [16, 18, 10765, 10759],
#    'id': 94605,
#    'name': 'Arcane',
#    'origin_country': ['US'],
# ...

# %%
df = pd.DataFrame(response)

# %%
df.head()
# Out:
#    page                                            results  total_pages  \
# 0     1  {'backdrop_path': '/tsRy63Mu5cu8etL1X7ZLyf7UP1...          152
# 1     1  {'backdrop_path': '/rkB4LyZHo1NHXFEDHl9vSD9r1l...          152
# 2     1  {'backdrop_path': '/4Mt7WHox67uJ1yErwTBFcV8KWg...          152
# 3     1  {'backdrop_path': '/9In9QgVJx7PlFOAgVHCKKSbo60...          152
# 4     1  {'backdrop_path': '/A6tMQAo6t6eRFCPhsrShmxZLqF...          152
#
#    total_results
# 0           3032
# 1           3032
# 2           3032
# 3           3032
# 4           3032

# %%
api_key = '87983fbe976988a9e22330ebf030a1ae'
base_url = 'https://api.themoviedb.org/3/'

discover_url = f'{base_url}discover/tv'
params = {
    'api_key': api_key,
    'first_air_date_year': 2022,
    'sort_by': 'vote_average.desc'
}

response = requests.get(discover_url, params=params)
data = response.json()

top_3_shows = data['results'][:3]

for show in top_3_shows:
   print(f"Title: {show['name']}, Rating: {show['vote_average']}")
# Out:
# Title: Bradley Walsh: The Laugh's on Me, Rating: 10
# Title: Abenteuer Spanien, Rating: 10
# Title: Snakes on the Brain, Rating: 10
